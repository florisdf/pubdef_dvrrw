# %%
from PIL import Image
import numpy as np
from torchvision.transforms.functional import to_tensor
from pathlib import Path

# %%
new_size = 50

im = (
    Image.open('images/waldek1.jpg')
    .convert('L')
    .resize((new_size, new_size))
)
im
# Out:
# <PIL.Image.Image image mode=L size=50x50 at 0x7FE2827277F0>

# %%
arr = (np.array(im)/255*100).astype(int)

Image.fromarray(((arr / 100)*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=50x50 at 0x7FE282760DC0>

# %%
lines = []
lines.append('const waldek = [')

for row in arr:
    lines.append(' '*4 + '[' + r', '.join(fr'{x}' for x in row) + '],')
lines.append('];')

lines.append('')
lines.append('export default waldek;')

text = '\n'.join(lines)
Path('../animations/image_palette/waldek.js').write_text(text)
# Out:
# 10336
