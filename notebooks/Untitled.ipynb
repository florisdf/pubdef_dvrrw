# %%
from sklearn.metrics import average_precision_score

# %%
average_precision_score(
    [False, True, True, False, False],
    [5, 4, 3, 2, 1]
)
# Out:
# 0.5833333333333333

# %%
average_precision_score(
    [False, False, True, False, True],
    [5, 4, 3, 2, 1]
)
# Out:
# 0.3666666666666667

# %%
average_precision_score(
    [True, True, False, False, False],
    [5, 4, 3, 2, 1]
)
# Out:
# 1.0

# %%
average_precision_score(
    [True, False, True, False, False],
    [5, 4, 3, 2, 1]
)
# Out:
# 0.8333333333333333

# %%
average_precision_score(
    [False, False, False, True, True],
    [5, 4, 3, 2, 1]
)
# Out:
# 0.325

# %%
average_precision_score(
    [True, True, False, False, False],
    [5, 4, 3, 2, 1]
)
# Out:
# 1.0

# %%
(0.5833333333333333 + 0.8333333333333333) / 2
# Out:
# 0.7083333333333333

# %%
(0.3666666666666667 + 0.325) / 2
# Out:
# 0.3458333333333333
